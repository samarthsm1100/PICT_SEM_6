# %% [markdown]
# ### Importing the required libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import set_theme

# %% [markdown]
# ### Load dataset into the dataframe

# %%
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# using the attribute information as the column names
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class']
df =  pd.read_csv(csv_url, names = col_names)

# %%
df.head(10)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %% [markdown]
# ### Data Types

# %%
df.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Class            object
# dtype: object

# %% [markdown]
# ### Histogram for each feature

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('Feature Distribution by Class')

sns.histplot(ax=axes[0, 0], data=df, x='Sepal_Length', hue='Class')
sns.histplot(ax=axes[0, 1], data=df, x='Sepal_Width', hue='Class')
sns.histplot(ax=axes[1, 0], data=df, x='Petal_Length', hue='Class')
sns.histplot(ax=axes[1, 1], data=df, x='Petal_Width', hue='Class')
# Out:
# <Axes: xlabel='Petal_Width', ylabel='Count'>

# %% [markdown]
# ### Boxplot

# %% [markdown]
# #### 1) Sepal Length

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('Feature Distribution by Class')

sns.boxplot(ax=axes[0, 0], data=df, x='Sepal_Length', y='Class', hue='Class')
sns.boxplot(ax=axes[0, 1], data=df, x='Sepal_Width', y='Class', hue='Class')
sns.boxplot(ax=axes[1, 0], data=df, x='Petal_Length', y='Class', hue='Class')
sns.boxplot(ax=axes[1, 1], data=df, x='Petal_Width', y='Class', hue='Class')
# Out:
# <Axes: xlabel='Petal_Width', ylabel='Class'>

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# #### 1) Sepal Length vs Sepal Width

# %%
sns.scatterplot(data = df, x = 'Sepal_Length', y = 'Sepal_Width', hue = 'Class')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %% [markdown]
# #### 2) Petal Length vs Petal Width

# %%
sns.scatterplot(data = df, x = 'Petal_Length', y = 'Petal_Width', hue = 'Class')
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Petal_Width'>

# %% [markdown]
# ### Conclusions :

# %% [markdown]
# 1) For Iris-setosa sepal-length, petal-length, petal-width is smaller and for Iris-virginica sepal-length, petal-length, petal-width is greater.
# 2) Sepal-width of Iris-setosa is greater than other two species.
# 3) From scatter plot and boxplot, it is clear that Iris-setosa has smaller length ratio of petal-length and petal-width.
# 4) From scatter plot and boxplot, it is seen that Iris-virginica has greater length ratio of petal-length and petal-width.
# 5) Iris-versicolor shows average features.
